# %%
from os import listdir
from os.path import isfile, join
mypath = "data/semantic_scholar_data"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
from num2words import num2words

# %%
num2words(10)
# Out:
# 'ten'

# %%
onlyfiles
# Out:
# ['breast+cancer_0.json',
#  'breast+cancer_100.json',
#  'breast+cancer_1000.json',
#  'breast+cancer_1100.json',
#  'breast+cancer_1200.json',
#  'breast+cancer_1300.json',
#  'breast+cancer_1400.json',
#  'breast+cancer_1500.json',
#  'breast+cancer_1600.json',
#  'breast+cancer_1700.json',
#  'breast+cancer_1800.json',
#  'breast+cancer_1900.json',
#  'breast+cancer_200.json',
#  'breast+cancer_2000.json',
#  'breast+cancer_2100.json',
#  'breast+cancer_2200.json',
#  'breast+cancer_2300.json',
#  'breast+cancer_2400.json',
#  'breast+cancer_2500.json',
#  'breast+cancer_2600.json',
#  'breast+cancer_2700.json',
#  'breast+cancer_2800.json',
#  'breast+cancer_2900.json',
#  'breast+cancer_300.json',
#  'breast+cancer_3000.json',
#  'breast+cancer_3100.json',
#  'breast+cancer_3200.json',
#  'breast+cancer_3300.json',
#  'breast+cancer_3400.json',
#  'breast+cancer_3500.json',
#  'breast+cancer_3600.json',
#  'breast+cancer_3700.json',
#  'breast+cancer_3800.json',
#  'breast+cancer_3900.json',
#  'breast+cancer_400.json',
#  'breast+cancer_4000.json',
#  'breast+cancer_4100.json',
#  'breast+cancer_4200.json',
#  'breast+cancer_4300.json',
#  'breast+cancer_4400.json',
#  'breast+cancer_4500.json',
#  'breast+cancer_4600.json',
#  'breast+cancer_4700.json',
#  'breast+cancer_4800.json',
#  'breast+cancer_4900.json',
#  'breast+cancer_500.json',
#  'breast+cancer_5000.json',
#  'breast+cancer_5100.json',
#  'breast+cancer_5200.json',
#  'breast+cancer_5300.json',
#  'breast+cancer_5400.json',
#  'breast+cancer_5500.json',
#  'breast+cancer_5600.json',
#  'breast+cancer_5700.json',
#  'breast+cancer_5800.json',
#  'breast+cancer_5900.json',
#  'breast+cancer_600.json',
#  'breast+cancer_6000.json',
#  'breast+cancer_6100.json',
#  'breast+cancer_6200.json',
#  'breast+cancer_6300.json',
#  'breast+cancer_6400.json',
#  'breast+cancer_6500.json',
#  'breast+cancer_6600.json',
#  'breast+cancer_6700.json',
#  'breast+cancer_6800.json',
#  'breast+cancer_6900.json',
#  'breast+cancer_700.json',
#  'breast+cancer_7000.json',
#  'breast+cancer_7100.json',
#  'breast+cancer_7200.json',
#  'breast+cancer_7300.json',
#  'breast+cancer_7400.json',
#  'breast+cancer_7500.json',
#  'breast+cancer_7600.json',
#  'breast+cancer_7700.json',
#  'breast+cancer_7800.json',
#  'breast+cancer_7900.json',
#  'breast+cancer_800.json',
#  'breast+cancer_8000.json',
#  'breast+cancer_8100.json',
#  'breast+cancer_8200.json',
#  'breast+cancer_8300.json',
#  'breast+cancer_8400.json',
#  'breast+cancer_8500.json',
#  'breast+cancer_8600.json',
#  'breast+cancer_8700.json',
#  'breast+cancer_8800.json',
#  'breast+cancer_8900.json',
#  'breast+cancer_900.json',
#  'breast+cancer_9000.json',
#  'breast+cancer_9100.json',
#  'breast+cancer_9200.json',
#  'breast+cancer_9300.json',
#  'breast+cancer_9400.json',
#  'breast+cancer_9500.json',
#  'breast+cancer_9600.json',
#  'breast+cancer_9700.json',
#  'breast+cancer_9800.json',
#  'prostate+cancer_0.json',
#  'prostate+cancer_100.json',
#  'prostate+cancer_1000.json',
#  'prostate+cancer_1100.json',
#  'prostate+cancer_1200.json',
#  'prostate+cancer_1300.json',
#  'prostate+cancer_1400.json',
#  'prostate+cancer_1500.json',
#  'prostate+cancer_1600.json',
#  'prostate+cancer_1700.json',
#  'prostate+cancer_1800.json',
#  'prostate+cancer_1900.json',
#  'prostate+cancer_200.json',
#  'prostate+cancer_2000.json',
#  'prostate+cancer_2100.json',
#  'prostate+cancer_2200.json',
#  'prostate+cancer_2300.json',
#  'prostate+cancer_2400.json',
#  'prostate+cancer_2500.json',
#  'prostate+cancer_2600.json',
#  'prostate+cancer_2700.json',
#  'prostate+cancer_2800.json',
#  'prostate+cancer_2900.json',
#  'prostate+cancer_300.json',
#  'prostate+cancer_3000.json',
#  'prostate+cancer_3100.json',
#  'prostate+cancer_3200.json',
#  'prostate+cancer_3300.json',
#  'prostate+cancer_3400.json',
#  'prostate+cancer_3500.json',
#  'prostate+cancer_3600.json',
#  'prostate+cancer_3700.json',
#  'prostate+cancer_3800.json',
#  'prostate+cancer_3900.json',
#  'prostate+cancer_400.json',
#  'prostate+cancer_4000.json',
#  'prostate+cancer_4100.json',
#  'prostate+cancer_4200.json',
#  'prostate+cancer_4300.json',
#  'prostate+cancer_4400.json',
#  'prostate+cancer_4500.json',
#  'prostate+cancer_4600.json',
#  'prostate+cancer_4700.json',
#  'prostate+cancer_4800.json',
#  'prostate+cancer_4900.json',
#  'prostate+cancer_500.json',
#  'prostate+cancer_5000.json',
#  'prostate+cancer_5100.json',
#  'prostate+cancer_5200.json',
#  'prostate+cancer_5300.json',
#  'prostate+cancer_5400.json',
#  'prostate+cancer_5500.json',
#  'prostate+cancer_5600.json',
#  'prostate+cancer_5700.json',
#  'prostate+cancer_5800.json',
#  'prostate+cancer_5900.json',
#  'prostate+cancer_600.json',
#  'prostate+cancer_6000.json',
#  'prostate+cancer_6100.json',
#  'prostate+cancer_6200.json',
#  'prostate+cancer_6300.json',
#  'prostate+cancer_6400.json',
#  'prostate+cancer_6500.json',
#  'prostate+cancer_6600.json',
#  'prostate+cancer_6700.json',
#  'prostate+cancer_6800.json',
#  'prostate+cancer_6900.json',
#  'prostate+cancer_700.json',
#  'prostate+cancer_7000.json',
#  'prostate+cancer_7100.json',
#  'prostate+cancer_7200.json',
#  'prostate+cancer_7300.json',
#  'prostate+cancer_7400.json',
#  'prostate+cancer_7500.json',
#  'prostate+cancer_7600.json',
#  'prostate+cancer_7700.json',
#  'prostate+cancer_7800.json',
#  'prostate+cancer_7900.json',
#  'prostate+cancer_800.json',
#  'prostate+cancer_8000.json',
#  'prostate+cancer_8100.json',
#  'prostate+cancer_8200.json',
#  'prostate+cancer_8300.json',
#  'prostate+cancer_8400.json',
#  'prostate+cancer_8500.json',
#  'prostate+cancer_8600.json',
#  'prostate+cancer_8700.json',
#  'prostate+cancer_8800.json',
#  'prostate+cancer_8900.json',
#  'prostate+cancer_900.json',
#  'prostate+cancer_9000.json',
#  'prostate+cancer_9100.json',
#  'prostate+cancer_9200.json',
#  'prostate+cancer_9300.json',
#  'prostate+cancer_9400.json',
#  'prostate+cancer_9500.json',
#  'prostate+cancer_9600.json',
#  'prostate+cancer_9700.json',
#  'prostate+cancer_9800.json',
#  'skin+cancer_0.json',
#  'skin+cancer_100.json',
#  'skin+cancer_1000.json',
#  'skin+cancer_1100.json',
#  'skin+cancer_1200.json',
#  'skin+cancer_1300.json',
#  'skin+cancer_1400.json',
#  'skin+cancer_1500.json',
#  'skin+cancer_1600.json',
#  'skin+cancer_1700.json',
#  'skin+cancer_1800.json',
#  'skin+cancer_1900.json',
#  'skin+cancer_200.json',
#  'skin+cancer_2000.json',
#  'skin+cancer_2100.json',
#  'skin+cancer_2200.json',
#  'skin+cancer_2300.json',
#  'skin+cancer_2400.json',
#  'skin+cancer_2500.json',
#  'skin+cancer_2600.json',
#  'skin+cancer_2700.json',
#  'skin+cancer_2800.json',
#  'skin+cancer_2900.json',
#  'skin+cancer_300.json',
#  'skin+cancer_3000.json',
#  'skin+cancer_3100.json',
#  'skin+cancer_3200.json',
#  'skin+cancer_3300.json',
#  'skin+cancer_3400.json',
#  'skin+cancer_3500.json',
#  'skin+cancer_3600.json',
#  'skin+cancer_3700.json',
#  'skin+cancer_3800.json',
#  'skin+cancer_3900.json',
#  'skin+cancer_400.json',
#  'skin+cancer_4000.json',
#  'skin+cancer_4100.json',
#  'skin+cancer_4200.json',
#  'skin+cancer_4300.json',
#  'skin+cancer_4400.json',
#  'skin+cancer_4500.json',
#  'skin+cancer_4600.json',
#  'skin+cancer_4700.json',
#  'skin+cancer_4800.json',
#  'skin+cancer_4900.json',
#  'skin+cancer_500.json',
#  'skin+cancer_5000.json',
#  'skin+cancer_5100.json',
#  'skin+cancer_5200.json',
#  'skin+cancer_5300.json',
#  'skin+cancer_5400.json',
#  'skin+cancer_5500.json',
#  'skin+cancer_5600.json',
#  'skin+cancer_5700.json',
#  'skin+cancer_5800.json',
#  'skin+cancer_5900.json',
#  'skin+cancer_600.json',
#  'skin+cancer_6000.json',
#  'skin+cancer_6100.json',
#  'skin+cancer_6200.json',
#  'skin+cancer_6300.json',
#  'skin+cancer_6400.json',
#  'skin+cancer_6500.json',
#  'skin+cancer_6600.json',
#  'skin+cancer_6700.json',
#  'skin+cancer_6800.json',
#  'skin+cancer_6900.json',
#  'skin+cancer_700.json',
#  'skin+cancer_7000.json',
#  'skin+cancer_7100.json',
#  'skin+cancer_7200.json',
#  'skin+cancer_7300.json',
#  'skin+cancer_7400.json',
#  'skin+cancer_7500.json',
#  'skin+cancer_7600.json',
#  'skin+cancer_7700.json',
#  'skin+cancer_7800.json',
#  'skin+cancer_7900.json',
#  'skin+cancer_800.json',
#  'skin+cancer_8000.json',
#  'skin+cancer_8100.json',
#  'skin+cancer_8200.json',
#  'skin+cancer_8300.json',
#  'skin+cancer_8400.json',
#  'skin+cancer_8500.json',
#  'skin+cancer_8600.json',
#  'skin+cancer_8700.json',
#  'skin+cancer_8800.json',
#  'skin+cancer_8900.json',
#  'skin+cancer_900.json',
#  'skin+cancer_9000.json',
#  'skin+cancer_9100.json',
#  'skin+cancer_9200.json',
#  'skin+cancer_9300.json',
#  'skin+cancer_9400.json',
#  'skin+cancer_9500.json',
#  'skin+cancer_9600.json',
#  'skin+cancer_9700.json',
#  'skin+cancer_9800.json']
