# %%
# !pip install owlready2
# Out:
# ...
#   Created wheel for owlready2: filename=Owlready2-0.35-cp38-cp38-win_amd64.whl size=19939771 sha256=8a598d538f7e532b18d74cc5e82776802d5bab3e32ada2f6b23ae5cd6d39f9a5
#   Stored in directory: c:\users\colmj\appdata\local\pip\cache\wheels\dc\30\4a\fbc1efb29207f08c8397c0a865f68b40b9f57752ab37e9dff5
# Successfully built owlready2
# ...

# %%
from owlready2 import *
from owlready2.pymedtermino2.umls import *

# %%
import_umls(r"C:\Users\Colmj\Desktop\UL_PHD_COURSEWORK\UL_Cancer_Network_Project\PyMedTermino\Resources\umls-2021AB-full.zip", terminologies = ["ICD10"])
# Out:
# Importing UMLS from C:\Users\Colmj\Desktop\UL_PHD_COURSEWORK\UL_Cancer_Network_Project\PyMedTermino\Resources\umls-2021AB-full.zip with Python version 3.8.3 and Owlready version 2-0.35...
# Full UMLS release - importing UMLS from inner Zip file 2021AB-full/2021ab-1-meta.nlm...
#   Parsing 2021AB/META/MRRANK.RRF.gz as MRRANK with encoding UTF-8
#   Parsing 2021AB/META/MRCONSO.RRF.aa.gz as MRCONSO with encoding UTF-8
#   Parsing 2021AB/META/MRCONSO.RRF.ab.gz as MRCONSO with encoding UTF-8
#   Parsing 2021AB/META/MRDEF.RRF.gz as MRDEF with encoding UTF-8
# Full UMLS release - importing UMLS from inner Zip file 2021AB-full/2021ab-2-meta.nlm...
#   Parsing 2021AB/META/MRREL.RRF.aa.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRREL.RRF.ab.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRREL.RRF.ac.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRREL.RRF.ad.gz as MRREL with encoding UTF-8
#   Parsing 2021AB/META/MRSAT.RRF.aa.gz as MRSAT with encoding UTF-8
# ...

# %%
#default_world.save()

# %%
PYM = get_ontology("http://PYM/").load()

# %%
PYM.search(keywords="Melanoma")
# Out:
# [SNOMEDCT_US["2092003"] # Malignant melanoma
# , SNOMEDCT_US["372244006"] # Malignant melanoma
# , SNOMEDCT_US["93655004"] # Malignant melanoma of skin
# , ICD10["C43.9"] # Malignant melanoma of skin, unspecified
# , ICD10["C43"] # Malignant melanoma of skin
# , ICD10["C43.0"] # Malignant melanoma of lip
# , SNOMEDCT_US["188030005"] # Malignant melanoma of lip
# , SNOMEDCT_US["93640008"] # Malignant melanoma of skin of lip
# , SNOMEDCT_US["93653006"] # Malignant melanoma of skin of upper limb
# , SNOMEDCT_US["93641007"] # Malignant melanoma of skin of lower limb
# , SNOMEDCT_US["83284001"] # Clark melanoma level 1
# , SNOMEDCT_US["50542000"] # Clark melanoma level 2
# , SNOMEDCT_US["21165006"] # Clark melanoma level 3
# , SNOMEDCT_US["1556006"] # Clark melanoma level 4
# , SNOMEDCT_US["16034002"] # Clark melanoma level 5
# , SNOMEDCT_US["106243009"] # Breslow depth staging for melanoma of skin
# , SNOMEDCT_US["402561003"] # Malignant melanoma of soft tissues
# ...
